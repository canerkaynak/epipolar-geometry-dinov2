# %% [markdown]
# ### **Mount to the Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/epipolar-geometry-dinov2/epipolar-geometry-dinov2
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/epipolar-geometry-dinov2/epipolar-geometry-dinov2

# %%
# Run the command below if you need
# !pip install -q -r requirements.txt

# %%
from src.data_loader import download_kitti_metadata, download_kitti_images

base_dir = '/content/drive/MyDrive/epipolar-geometry-dinov2/epipolar-geometry-dinov2/data/kitti_sample'

# Downloads metadata (calib, poses, times)
download_kitti_metadata(base_dir, sequence="00")

# Download first 150 stereo images
download_kitti_images(base_dir, sequence="00", num_frames=150)
